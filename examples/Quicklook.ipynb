# %%
import sys
sys.path.append('..')
# %matplotlib notebook
from sdc import QuickLook

# %%
lc=QuickLook.LightCurves('2021-05-07T00:00:00', '2021-05-08T00:00:00', ltc=True)
lc.peek()
# Out:
# <img src="data:image/png;base64,..." width="805.3333333333334">

# %%
lc.data['energy_bins']
# Out:
# {'names': ['4  – 10 keV',
#   '10  – 15 keV',
#   '15  – 25 keV',
#   '25  – 50 keV',
#   '50  – 84 keV'],
#  'sci_bin_edges': [[1, 7], [7, 12], [12, 17], [17, 23], [23, 28]]}
