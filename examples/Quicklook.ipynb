# %%
import sys
sys.path.append('..')
import numpy as np

from sdcpy import QuickLook
from sdcpy import Calibration

# %matplotlib notebook

# %% [markdown]
# # Retrieve and plot Quick-look data

# %%
lc=QuickLook.LightCurves('2021-05-07T00:00:00', '2021-05-08T00:00:00', ltc=True)
lc.peek()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lc.data['energy_bins']
# Out:
# {'names': ['4  – 10 keV',
#   '10  – 15 keV',
#   '15  – 25 keV',
#   '25  – 50 keV',
#   '50  – 84 keV'],
#  'sci_bin_edges': [[1, 7], [7, 12], [12, 17], [17, 23], [23, 28]]}

# %% [markdown]
# # Retreive Calibration data

# %%
elut=Calibration.EnergyLUT('2021-09-01T00:00:00')

# %%
elut.info()
# Out:
# {'calibration_run': {'duration': 86400,
#                      'obs_begin': '2021-08-26T12:50:08.874',
#                      'run_id': 1348},
#  'onboard_elut': {'upload_time_range': ['2021-06-25T14:54:14.456',
#                                         '2021-06-25T14:55:49.456']}}
# 'Pixel 0 true energy bin  edges: '
# array([[3.30000e-02, 4.04400e+00],
#        [4.04400e+00, 5.04700e+00],
#        [5.04700e+00, 6.05000e+00],
#        [6.05000e+00, 7.05300e+00],
#        [7.05300e+00, 8.05600e+00],
#        [8.05600e+00, 9.05900e+00],
#        [9.05900e+00, 1.00620e+01],
#        [1.00620e+01, 1.10650e+01],
#        [1.10650e+01, 1.20670e+01],
#        [1.20670e+01, 1.30700e+01],
#        [1.30700e+01, 1.40730e+01],
#        [1.40730e+01, 1.50760e+01],
#        [1.50760e+01, 1.60790e+01],
#        [1.60790e+01, 1.80850e+01],
#        [1.80850e+01, 2.00910e+01],
#        [2.00910e+01, 2.20960e+01],
#        [2.20960e+01, 2.51050e+01],
#        [2.51050e+01, 2.81140e+01],
# ...

# %%
elut.get_pixel_true_ebins(4)
# Out:
# array([[-4.00000e-02,  3.97400e+00],
#        [ 3.97400e+00,  4.97700e+00],
#        [ 4.97700e+00,  5.98000e+00],
#        [ 5.98000e+00,  6.98400e+00],
#        [ 6.98400e+00,  7.98700e+00],
#        [ 7.98700e+00,  8.99100e+00],
#        [ 8.99100e+00,  9.99400e+00],
#        [ 9.99400e+00,  1.09970e+01],
#        [ 1.09970e+01,  1.20010e+01],
#        [ 1.20010e+01,  1.30040e+01],
#        [ 1.30040e+01,  1.40080e+01],
#        [ 1.40080e+01,  1.50110e+01],
#        [ 1.50110e+01,  1.60140e+01],
#        [ 1.60140e+01,  1.80210e+01],
#        [ 1.80210e+01,  2.00280e+01],
#        [ 2.00280e+01,  2.20350e+01],
#        [ 2.20350e+01,  2.50450e+01],
#        [ 2.50450e+01,  2.80550e+01],
#        [ 2.80550e+01,  3.20680e+01],
#        [ 3.20680e+01,  3.60820e+01],
#        [ 3.60820e+01,  4.00960e+01],
#        [ 4.00960e+01,  4.51120e+01],
#        [ 4.51120e+01,  5.01290e+01],
#        [ 5.01290e+01,  5.61500e+01],
#        [ 5.61500e+01,  6.31730e+01],
# ...

# %%
#x[:,0]
