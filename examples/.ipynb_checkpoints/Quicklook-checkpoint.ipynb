# %%
import sys
sys.path.append('..')
import numpy as np

from sdcpy import QuickLook
from sdcpy import Calibration
from sdcpy import Ancillary as anc

# %matplotlib notebook

# %% [markdown]
# # Retrieve and plot Quick-look data

# %%
lc=QuickLook.LightCurves('2021-08-28T05:00:00', '2021-08-28T07:00:00', ltc=True)
lc.peek()
# Out:
# <img src="data:image/png;base64,..." width="832">

# %%
lc.data['energy_bins']
# Out:
# {'names': ['4  – 10 keV',
#   '10  – 15 keV',
#   '15  – 25 keV',
#   '25  – 50 keV',
#   '50  – 84 keV'],
#  'sci_bin_edges': [[1, 7], [7, 12], [12, 17], [17, 23], [23, 28]]}

# %% [markdown]
# # Retreive Calibration data

# %%
elut=Calibration.EnergyLUT('2021-08-28T00:00:00')

# %%
#Print onboard elut and calibration run information
#elut.info()

# %%
elut.get_pixel_true_ebins(pixel=4)
#print the energy range of bins of pixel 4
# Out:
# array([[-4.60000e-02,  3.96800e+00],
#        [ 3.96800e+00,  4.97100e+00],
#        [ 4.97100e+00,  5.97500e+00],
#        [ 5.97500e+00,  6.97800e+00],
#        [ 6.97800e+00,  7.98200e+00],
#        [ 7.98200e+00,  8.98500e+00],
#        [ 8.98500e+00,  9.98900e+00],
#        [ 9.98900e+00,  1.09920e+01],
#        [ 1.09920e+01,  1.19950e+01],
#        [ 1.19950e+01,  1.29990e+01],
#        [ 1.29990e+01,  1.40020e+01],
#        [ 1.40020e+01,  1.50060e+01],
#        [ 1.50060e+01,  1.60090e+01],
#        [ 1.60090e+01,  1.80160e+01],
#        [ 1.80160e+01,  2.00230e+01],
#        [ 2.00230e+01,  2.20300e+01],
#        [ 2.20300e+01,  2.50400e+01],
#        [ 2.50400e+01,  2.80500e+01],
#        [ 2.80500e+01,  3.20640e+01],
#        [ 3.20640e+01,  3.60780e+01],
#        [ 3.60780e+01,  4.00910e+01],
#        [ 4.00910e+01,  4.51080e+01],
#        [ 4.51080e+01,  5.01260e+01],
#        [ 5.01260e+01,  5.61460e+01],
#        [ 5.61460e+01,  6.31700e+01],
# ...

# %% [markdown]
# # Retreive and plot empheris
