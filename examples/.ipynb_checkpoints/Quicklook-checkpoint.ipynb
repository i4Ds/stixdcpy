# %%
import sys
sys.path.append('..')
# %matplotlib notebook

from sdc import QuickLook

lc=QuickLook.LightCurves('2021-05-07T00:00:00', '2021-05-08T00:00:00')
lc.peek()
# Out:
# <img src="data:image/png;base64,..." width="640">
